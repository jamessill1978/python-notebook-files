# %%
from arcgis.gis import GIS
from getpass import getpass
from IPython.display import display

# %%
gis = GIS('https://lnr.maps.arcgis.com', username="")

# %%
display(gis)
# Out:
# GIS @ <a href="https://lnr.maps.arcgis.com">https://lnr.maps.arcgis.com</a>

# %%
lnr_user = lnr.users.roles

# %%
lnr_user

# %%
gis.admin.license.all()
# Out:
# [<Insights for ArcGIS License at https://lnr.maps.arcgis.com/sharing/rest/>,
#  <Redistricting Online License at https://lnr.maps.arcgis.com/sharing/rest/>,
#  <ArcGIS Pro License at https://lnr.maps.arcgis.com/sharing/rest/>,
#  <Drone2Map for ArcGIS License at https://lnr.maps.arcgis.com/sharing/rest/>,
#  <GeoPlanner for ArcGIS License at https://lnr.maps.arcgis.com/sharing/rest/>,
#  <License at https://lnr.maps.arcgis.com/sharing/rest/>,
#  <AppStudio for ArcGIS Standard License at https://lnr.maps.arcgis.com/sharing/rest/>,
#  <ArcGIS Community Analyst License at https://lnr.maps.arcgis.com/sharing/rest/>,
#  <Navigator for ArcGIS License at https://lnr.maps.arcgis.com/sharing/rest/>,
#  <Admin Tools for ArcGIS℠ Online License at https://lnr.maps.arcgis.com/sharing/rest/>,
#  <ArcGIS Business Analyst License at https://lnr.maps.arcgis.com/sharing/rest/>]

# %%
pro_license = gis.admin.license.get('ArcGIS Pro')
pro_license
# Out:
# <ArcGIS Pro License at https://lnr.maps.arcgis.com/sharing/rest/>

# %%
type(pro_license)
# Out:
# arcgis.gis.admin._license.License

# %%
pro_license.all()
# Out:
# [{'disconnected': False,
#   'entitlements': ['3DAnalystN',
#    'dataInteropN',
#    'dataReviewerN',
#    'desktopAdvN',
#    'geostatAnalystN',
#    'LocRefDesktopN',
#    'networkAnalystN',
#    'smpAsiaPacificN',
#    'smpEuropeN',
#    'smpMidEAfricaN',
#    'smpNAmericaN',
#    'spatialAnalystN',
#    'workflowMgrN'],
#   'lastLogin': 1502828871000,
#   'username': 'amartin_lnr'},
#  {'disconnected': False,
#   'entitlements': ['3DAnalystN',
#    'dataReviewerN',
#    'desktopAdvN',
#    'geostatAnalystN',
#    'networkAnalystN',
#    'spatialAnalystN',
#    'workflowMgrN'],
#   'lastLogin': -1,
#   'username': 'ataylor_LNR'},
#  {'disconnected': False,
#   'entitlements': ['dataReviewerN',
#    'desktopStdN',
#    'geostatAnalystN',
#    'networkAnalystN',
#    'spatialAnalystN',
#    'workflowMgrN'],
#   'lastLogin': 1519410119000,
#   'username': 'bknott_LNR'},
#  {'disconnected': False,
#   'entitlements': ['3DAnalystN',
#    'airportsN',
#    'dataInteropN',
#    'dataReviewerN',
#    'defenseN',
#    'desktopAdvN',
#    'geostatAnalystN',
#    'LocRefDesktopN',
#    'networkAnalystN',
#    'publisherN',
#    'smpAsiaPacificN',
#    'smpEuropeN',
#    'smpLAmericaN',
#    'smpMidEAfricaN',
#    'smpNAmericaN',
#    'spatialAnalystN',
#    'workflowMgrN'],
#   'lastLogin': -1,
#   'username': 'brose_LNR'},
#  {'disconnected': False,
#   'entitlements': ['3DAnalystN',
#    'dataReviewerN',
#    'desktopAdvN',
#    'geostatAnalystN',
#    'networkAnalystN',
#    'spatialAnalystN',
#    'workflowMgrN'],
#   'lastLogin': 1496688263000,
#   'username': 'bstayer_LNR'},
#  {'disconnected': False,
#   'entitlements': ['3DAnalystN',
#    'dataReviewerN',
#    'desktopAdvN',
#    'geostatAnalystN',
#    'networkAnalystN',
#    'smpEuropeN',
#    'smpNAmericaN',
#    'spatialAnalystN',
#    'workflowMgrN'],
#   'lastLogin': 1499874918000,
#   'username': 'CMenzel_LNR'},
#  {'disconnected': False,
#   'entitlements': ['3DAnalystN',
#    'dataReviewerN',
#    'desktopAdvN',
#    'geostatAnalystN',
#    'networkAnalystN',
#    'smpEuropeN',
#    'smpNAmericaN',
#    'spatialAnalystN',
#    'workflowMgrN'],
#   'lastLogin': -1,
#   'username': 'dattaway_LNR'},
#  {'disconnected': False,
#   'entitlements': ['3DAnalystN',
#    'dataReviewerN',
#    'desktopAdvN',
#    'geostatAnalystN',
#    'networkAnalystN',
#    'spatialAnalystN',
#    'workflowMgrN'],
#   'lastLogin': -1,
#   'username': 'JGjika_LNR'},
#  {'disconnected': False,
#   'entitlements': ['3DAnalystN',
#    'dataReviewerN',
#    'desktopAdvN',
#    'geostatAnalystN',
#    'networkAnalystN',
#    'spatialAnalystN',
#    'workflowMgrN'],
#   'lastLogin': -1,
#   'username': 'JoFraley_LNR'},
#  {'disconnected': False,
#   'entitlements': ['3DAnalystN',
#    'airportsN',
#    'businessStdN',
#    'dataInteropN',
#    'dataReviewerN',
#    'defenseN',
#    'desktopAdvN',
#    'geostatAnalystN',
#    'imageAnalystN',
#    'LocRefDesktopN',
#    'maritimeN',
#    'networkAnalystN',
#    'productionMapN',
#    'publisherN',
#    'smpAsiaPacificN',
#    'smpEuropeN',
#    'smpLAmericaN',
#    'smpMidEAfricaN',
#    'smpNAmericaN',
#    'spatialAnalystN',
#    'workflowMgrN'],
#   'lastLogin': 1519510337000,
#   'username': 'jsill_lnr'},
#  {'disconnected': False,
#   'entitlements': ['3DAnalystN',
#    'dataReviewerN',
#    'desktopAdvN',
#    'geostatAnalystN',
#    'networkAnalystN',
#    'spatialAnalystN',
#    'workflowMgrN'],
#   'lastLogin': 1493850226000,
#   'username': 'jsteffenson_LNR'},
#  {'disconnected': False,
#   'entitlements': ['3DAnalystN',
#    'dataReviewerN',
#    'desktopAdvN',
#    'geostatAnalystN',
#    'networkAnalystN',
#    'spatialAnalystN',
#    'workflowMgrN'],
#   'lastLogin': -1,
#   'username': 'JVaughan_Gibson_LNR'},
#  {'disconnected': False,
#   'entitlements': ['3DAnalystN',
#    'dataReviewerN',
#    'desktopAdvN',
#    'geostatAnalystN',
#    'networkAnalystN',
#    'smpEuropeN',
#    'smpNAmericaN',
#    'spatialAnalystN',
#    'workflowMgrN'],
#   'lastLogin': 1519236950000,
#   'username': 'kgorton_lnr'},
#  {'disconnected': False,
#   'entitlements': ['3DAnalystN',
#    'airportsN',
#    'businessStdN',
#    'dataInteropN',
#    'dataReviewerN',
#    'defenseN',
#    'desktopAdvN',
#    'geostatAnalystN',
#    'imageAnalystN',
#    'LocRefDesktopN',
#    'maritimeN',
#    'networkAnalystN',
#    'productionMapN',
#    'publisherN',
#    'smpAsiaPacificN',
#    'smpEuropeN',
#    'smpLAmericaN',
#    'smpMidEAfricaN',
#    'smpNAmericaN',
#    'spatialAnalystN',
#    'workflowMgrN'],
#   'lastLogin': -1,
#   'username': 'khocutt_LNR'},
#  {'disconnected': False,
#   'entitlements': ['3DAnalystN',
#    'dataInteropN',
#    'desktopAdvN',
#    'geostatAnalystN',
#    'networkAnalystN',
#    'smpAsiaPacificN',
#    'smpEuropeN',
#    'smpLAmericaN',
#    'smpMidEAfricaN',
#    'smpNAmericaN',
#    'spatialAnalystN',
#    'workflowMgrN'],
#   'lastLogin': 1499364451000,
#   'username': 'mdefratti_LNR'},
#  {'disconnected': False,
#   'entitlements': ['3DAnalystN',
#    'dataInteropN',
#    'dataReviewerN',
#    'defenseN',
#    'desktopAdvN',
#    'geostatAnalystN',
#    'networkAnalystN',
#    'publisherN',
#    'spatialAnalystN'],
#   'lastLogin': -1,
#   'username': 'pobrien_LNR'},
#  {'disconnected': False,
#   'entitlements': ['3DAnalystN',
#    'dataReviewerN',
#    'desktopAdvN',
#    'geostatAnalystN',
#    'networkAnalystN',
#    'spatialAnalystN',
#    'workflowMgrN'],
#   'lastLogin': 1517248301000,
#   'username': 'sbryce_LNR'},
#  {'disconnected': False,
#   'entitlements': ['3DAnalystN',
#    'dataReviewerN',
#    'desktopAdvN',
#    'geostatAnalystN',
#    'networkAnalystN',
#    'spatialAnalystN',
#    'workflowMgrN'],
#   'lastLogin': -1,
#   'username': 'tedrick_LNR'},
#  {'disconnected': False,
#   'entitlements': ['desktopAdvN'],
#   'lastLogin': -1,
#   'username': 'tpenman_lnr'},
#  {'disconnected': False,
#   'entitlements': ['3DAnalystN',
#    'dataReviewerN',
#    'desktopAdvN',
#    'geostatAnalystN',
#    'networkAnalystN',
#    'spatialAnalystN',
#    'workflowMgrN'],
#   'lastLogin': -1,
#   'username': 'tshallpub_LNR'},
#  {'disconnected': False,
#   'entitlements': ['3DAnalystN',
#    'dataInteropN',
#    'dataReviewerN',
#    'defenseN',
#    'desktopAdvN',
#    'geostatAnalystN',
#    'networkAnalystN',
#    'publisherN',
#    'smpAsiaPacificN',
#    'smpEuropeN',
#    'smpLAmericaN',
#    'smpMidEAfricaN',
#    'smpNAmericaN',
#    'spatialAnalystN',
#    'workflowMgrN'],
#   'lastLogin': 1518724181000,
#   'username': 'tshall_LNR'}]

# %%
# %matplotlib inline

# %%
pro_license.plot()

# %%
pro_license.report
# Out:
#         Entitlement  Total  Assigned  Remaining
# 0        3DAnalystN    100        19         81
# 1         airportsN    100         3         97
# 2      businessStdN    100         2         98
# 3      dataInteropN    100         7         93
# 4     dataReviewerN    100        19         81
# 5          defenseN    100         5         95
# 6       desktopAdvN    100        20         80
# 7     desktopBasicN    100         0        100
# 8       desktopStdN    100         1         99
# 9   geostatAnalystN    100        20         80
# 10    imageAnalystN    100         2         98
# 11   LocRefDesktopN    100         4         96
# 12        maritimeN    100         2         98
# 13  networkAnalystN    100        20         80
# 14   productionMapN    100         2         98
# 15       publisherN    100         5         95
# 16  smpAsiaPacificN    100         6         94
# 17       smpEuropeN    100         9         91
# 18     smpLAmericaN    100         5         95
# 19   smpMidEAfricaN    100         6         94
# 20     smpNAmericaN    100         9         91
# 21  spatialAnalystN    100        20         80
# 22     workflowMgrN    100        19         81
